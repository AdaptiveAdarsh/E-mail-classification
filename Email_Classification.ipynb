# %%
## Importing the necessary libraries along with the standard import
import numpy as np 
import pandas as pd 
# regular expression is a package which helps to search certain text (particular text) or string in the data as well do some
# manipulation to the strings or the data
import re # this is the regular expression library which helps us manipulate text (strings) fairly easily and intuitively
import nltk # this is the Natural Language Tool Kit which contains a lot of functionalities for text analytics
import matplotlib.pyplot as plt
import string # this is used for string manipulations
import matplotlib

# %%
import scipy as sp
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
# %matplotlib inline

# %%
email_class = pd.read_table('sms.tsv', names=['label','message'])
email_class.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
email_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    5572 non-null   int64
#  1   message  5572 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 87.2+ KB

# %%
email_class.isnull().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %%
email_class['label']= email_class['label'].replace('ham',0).replace('spam',1)

# %%
email_class.head()
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
email_class['label'].value_counts(normalize=True)*100
# Out:
# 0    86.593683
# 1    13.406317
# Name: label, dtype: float64

# %% [markdown]
# **Number of Stop Words**

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Shefali\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
email_class['stopwords'] = email_class['message'].apply(lambda x: len([x for x in x.split() if x in stop]))
email_class[['message','stopwords']].head()
# Out:
#                                              message  stopwords
# 0  Go until jurong point, crazy.. Available only ...          4
# 1                      Ok lar... Joking wif u oni...          0
# 2  Free entry in 2 a wkly comp to win FA Cup fina...          5
# 3  U dun say so early hor... U c already then say...          2
# 4  Nah I don't think he goes to usf, he lives aro...          5

# %% [markdown]
# **Remove the stop words**

# %%
email_class['message'] = email_class['message'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
email_class['message'].head()
# Out:
# 0    Go jurong point, crazy.. Available bugis n gre...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry 2 wkly comp win FA Cup final tkts 2...
# 3            U dun say early hor... U c already say...
# 4            Nah I think goes usf, lives around though
# Name: message, dtype: object

# %% [markdown]
# **Remove special characters**

# %%
email_class['message']= email_class['message'].str.replace('[^\w\s]','')
# Out:
# C:\Users\Shefali\AppData\Local\Temp\ipykernel_26236\79223765.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   email_class['message']= email_class['message'].str.replace('[^\w\s]','')

# %% [markdown]
# **All words into Lower Case**

# %%
email_class['message'] = email_class['message'].apply(lambda x: " ".join(x.lower() for x in x.split()))
email_class['message'].head()
# Out:
# 0    go jurong point crazy available bugis n great ...
# 1                              ok lar joking wif u oni
# 2    free entry 2 wkly comp win fa cup final tkts 2...
# 3                  u dun say early hor u c already say
# 4             nah i think goes usf lives around though
# Name: message, dtype: object

# %% [markdown]
# **Commonly used words**

# %%
common_words = pd.Series(' '.join(email_class['message']).split()).value_counts()[:50]
common_words
# Out:
# i        1491
# u        1132
# call      578
# you       502
# 2         482
# im        473
# ur        390
# get       386
# 4         293
# now       288
# go        281
# ok        278
# ltgt      276
# free      275
# know      257
# like      244
# ill       243
# got       239
# good      236
# me        230
# come      229
# it        225
# no        210
# time      208
# day       203
# love      200
# want      193
# send      191
# text      188
# dont      185
# one       171
# going     171
# ü         169
# need      167
# txt       163
# home      162
# lor       160
# do        159
# see       157
# sorry     156
# still     154
# r         153
# back      152
# stop      152
# how       152
# but       148
# n         146
# if        144
# reply     144
# so        144
# dtype: int64

# %% [markdown]
# **Remove some of the Words**

# %%
word_removal=['i','u','2','im','ur','4','ltgt','it','ü','r','n']

# %%
email_class['message']= email_class['message'].apply(lambda x: " ".join(x for x in x.split() if x not in word_removal))
email_class['message'].head()
# Out:
# 0    go jurong point crazy available bugis great wo...
# 1                                ok lar joking wif oni
# 2    free entry wkly comp win fa cup final tkts 21s...
# 3                      dun say early hor c already say
# 4               nah think goes usf lives around though
# Name: message, dtype: object

# %% [markdown]
# **Low Frequently used words**

# %%
Not_frequent = pd.Series(' '.join(email_class['message']).split()).value_counts()[-50:]
Not_frequent
# Out:
# occupied             1
# tables               1
# lololo               1
# waaaat               1
# nosh                 1
# nevering             1
# manual               1
# sfrom                1
# needa                1
# andor                1
# washob               1
# annoncement          1
# 087123002209am7pm    1
# attach               1
# guesses              1
# supplies             1
# lara                 1
# 07046744435          1
# readiness            1
# noisy                1
# simulate             1
# autocorrect          1
# audrie               1
# samachara            1
# mathe                1
# howda                1
# envy                 1
# sees                 1
# nobbing              1
# nickey               1
# platt                1
# ryan                 1
# dirt                 1
# chores               1
# rejected             1
# ipaditan             1
# ponnungale           1
# intha                1
# hesitation           1
# exist                1
# hall                 1
# hail                 1
# problemfree          1
# sterling             1
# province             1
# spotty               1
# mist                 1
# aaooooright          1
# meare                1
# bitching             1
# dtype: int64

# %%
word_removal=['lololo','aaooooright','intha','ponnungale']

# %%
email_class['message'] = email_class['message'].apply(lambda x: " ".join(x for x in x.split() if x not in word_removal))
email_class['message'].head()
# Out:
# 0    go jurong point crazy available bugis great wo...
# 1                                ok lar joking wif oni
# 2    free entry wkly comp win fa cup final tkts 21s...
# 3                      dun say early hor c already say
# 4               nah think goes usf lives around though
# Name: message, dtype: object

# %% [markdown]
# **Lemmatization**

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Shefali\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizerword = WordNetLemmatizer()

email_class['message'][:5].apply(lambda x: " ".join([lemmatizerword.lemmatize(i) for i in x.split()]))
# Out:
# 0    go jurong point crazy available bugis great wo...
# 1                                ok lar joking wif oni
# 2    free entry wkly comp win fa cup final tkts 21s...
# 3                      dun say early hor c already say
# 4                  nah think go usf life around though
# Name: message, dtype: object

# %% [markdown]
# **Analysis -Spam and Ham**

# %%
email_class.label.value_counts().plot(kind='pie', 
                                       autopct='%1.0f%%', 
                                       colors=["Yellow","red"],
                                     explode=[0,1])
plt.show()

# %% [markdown]
# **Visualizing Ham and Spam**

# %%
from wordcloud import WordCloud,STOPWORDS

Negatives=email_class[(email_class['label']==1)]
N_words = ' '.join(Negatives['message'])
N_words
# Out:
# 'free entry wkly comp win fa cup final tkts 21st may 2005 text fa 87121 receive entry questionstd txt ratetcs apply 08452810075over18s freemsg hey darling 3 weeks word back id like fun still tb ok xxx std chgs send 150 rcv winner as valued network customer selected receivea 900 prize reward to claim call 09061701461 claim code kl341 valid 12 hours only had mobile 11 months more entitled update latest colour mobiles camera free call the mobile update co free 08002986030 six chances win cash from 100 20000 pounds txt csh11 send 87575 cost 150pday 6days 16 tsandcs apply reply hl info urgent you 1 week free membership 100000 prize jackpot txt word claim no 81010 tc wwwdbuknet lccltd pobox 4403ldnw1a7rw18 xxxmobilemovieclub to use credit click wap link next txt message click here httpwap xxxmobilemovieclubcomnqjkgighjjgcbl england v macedonia dont miss goalsteam news txt national team 87077 eg england 87077 trywales scotland 4txtú120 poboxox36504w45wq 16 thanks subscription ringtone uk mobile charged 5month please confirm replying yes no if reply no charged 07732584351 rodger burns msg we tried call reply sms free nokia mobile free camcorder please call 08000930705 delivery tomorrow sms ac sptv the new jersey devils detroit red wings play ice hockey correct incorrect end reply end sptv congrats 1 year special cinema pass yours call 09061209465 now c suprman v matrix3 starwars3 etc free bx420ip45we 150pm dont miss out as valued customer pleased advise following recent review mob no awarded 1500 bonus prize call 09066364589 urgent awarded complimentary trip eurodisinc trav acoentry41 or 1000 to claim txt dis 87121 186150morefrmmob shracomorsglsuplt10 ls1 3aj did hear new divorce barbie comes kens stuff please call customer service representative 0800 169 6031 10am9pm won guaranteed 1000 cash 5000 prize your free ringtone waiting collected simply text password mix 85069 verify get usher britney fml po box 5249 mk17 92h 450ppw 16 gent we trying contact you last weekends draw shows 1000 prize guaranteed call 09064012160 claim code k52 valid 12hrs only 150ppm you winner specially selected receive 1000 holiday flights inc speak live operator claim 0871277810910pmin 18 private your 2004 account statement 07742676969 shows 786 unredeemed bonus points to claim call 08719180248 identifier code 45239 expires urgent your mobile no awarded 2000 bonus caller prize 5903 this final try contact call landline 09064019788 box42wr29c 150ppm todays voda numbers ending 7548 selected receive 350 award if match please call 08712300220 quoting claim code 4041 standard rates app sunshine quiz wkly q win top sony dvd player know country algarve in txt ansr 82277 150 sptyrone want get laid tonight want real dogging locations sent direct mob join uks largest dogging network bt txting gravel 69888 nt ec2a 31pmsg150p youll rcv msgs chat svc for free hardcore services text go to 69988 if get nothing must age verify yr network try freemsg why replied text randy sexy female live local luv hear netcollex ltd 08700621170150p per msg reply stop end customer service annoncement you new years delivery waiting you please call 07046744435 arrange delivery you winner specially selected receive 1000 cash holiday flights inc speak live operator claim 0871277810810 pls stop bootydelious 32f inviting friend reply yes434 no434 see her wwwsmsacubootydelious stop send stop frnd 62468 bangbabes order way should receive service msg download content if not goto wap bangb tv mobile internetservice menu urgent we trying contact you last weekends draw shows 900 prize guaranteed call 09061701939 claim code s89 valid 12hrs please call customer service representative freephone 0808 145 4742 9am11pm won guaranteed 1000 cash 5000 prize are unique enough find 30th august wwwareyouuniquecouk 500 new mobiles 2004 must go txt nokia no 89545 collect todayfrom only 1 www4tcbiz 2optout 08718726270150gbpmtmsg18 will meet dream partner soon is career flyng start find free txt horo followed star sign  ...

# %%
wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color='black',
                      width=2000,
                      height=2000
                     ).generate(N_words)

plt.figure(1,figsize=(10, 10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# **Email Sentiments**

# %%
email_sentiments = email_class[['message','label']]

# %%
X = email_sentiments.message
y = email_sentiments.label

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, 
                                                y, 
                                                random_state=0)

# %% [markdown]
# **Document Term Matrix -DTM**

# %%
vector = CountVectorizer(stop_words='english',min_df=3)

# %%
vector.fit(Xtrain)
vector.vocabulary_
# Out:
# {'going': 767,
#  'need': 1199,
#  'little': 1026,
#  'experience': 646,
#  'understand': 1832,
#  'american': 186,
#  'customer': 498,
#  'voice': 1872,
#  'secret': 1513,
#  'admirer': 155,
#  'thinks': 1745,
#  'special': 1620,
#  'opt': 1253,
#  'reply': 1441,
#  'stop': 1651,
#  '150': 35,
#  'msg': 1178,
#  'recd': 1416,
#  'cust': 496,
#  'care': 366,
#  'ok': 1239,
#  'huh': 873,
#  'park': 1275,
#  'ah': 167,
#  'got': 776,
#  'best': 276,
#  'choice': 409,
#  'den': 535,
#  'juz': 954,
#  'just': 953,
#  'wasnt': 1897,
#  'pissed': 1308,
#  'remember': 1434,
#  'gone': 769,
#  'text': 1727,
#  'word': 1961,
#  'mobile': 1148,
#  'phone': 1293,
#  'send': 1523,
#  'wats': 1903,
#  'da': 503,
#  'model': 1154,
#  'num': 1227,
#  'sorry': 1612,
#  'ill': 891,
#  'later': 989,
#  'worries': 1969,
#  'hope': 855,
#  'photo': 1295,
#  'shoot': 1548,
#  'went': 1924,
#  'fun': 731,
#  'checking': 399,
#  'iq': 919,
#  'nokia': 1216,
#  'tone': 1779,
#  'mob': 1147,
#  'week': 1915,
#  'txt': 1816,
#  '87021': 120,
#  '1st': 45,
#  'free': 711,
#  'txtin': 1818,
#  'tell': 1718,
#  'friends': 720,
#  '150ptone': 41,
#  '16': 42,
#  'hl': 840,
#  '4info': 87,
#  'hi': 834,
#  'ard': 208,
#  'christmas': 411,
#  'enjoy': 618,
#  'merry': 1122,
#  'xmas': 1988,
#  'tmr': 1769,
#  'lar': 987,
#  'aiya': 175,
#  'come': 435,
#  'mayb': 1104,
#  'neva': 1204,
#  'set': 1533,
#  'help': 829,
#  'wif': 1933,
#  'lol': 1037,
#  'til': 1758,
#  'nite': 1213,
#  'imma': 893,
#  'definitely': 531,
#  'thanksgiving': 1733,
#  'let': 1008,
#  'know': 976,
#  'guy': 792,
#  'like': 1018,
#  'id': 883,
#  'interested': 911,
#  'buying': 342,
#  'gave': 743,
#  'ive': 927,
#  'reached': 1404,
#  'sch': 1500,
#  'hurry': 876,
#  'home': 852,
#  'yijue': 2005,
#  'regarding': 1425,
#  'intro': 915,
#  'second': 1511,
#  'selling': 1521,
#  '50': 92,
#  'nope': 1219,
#  'talk': 1701,
#  'say': 1496,
#  'make': 1083,
#  'greet': 784,
#  'telling': 1719,
#  'treat': 1796,
#  'kallis': 956,
#  'town': 1790,
#  'luv': 1073,
#  'ya': 1992,
#  'exam': 637,
#  'dnt': 562,
#  'live': 1027,
#  'thnk': 1747,
#  'different': 547,
#  'wah': 1879,
#  'lucky': 1071,
#  'man': 1086,
#  'save': 1494,
#  'money': 1161,
#  'hee': 824,
#  'din': 551,
#  'yup': 2018,
#  'cut': 499,
#  'hair': 799,
#  'pick': 1298,
#  'drop': 588,
#  'door': 575,
#  'think': 1742,
#  'waiting': 1882,
#  'bus': 339,
#  'inform': 904,
#  'knw': 978,
#  'vl': 1869,
#  'thanks': 1732,
#  'wit': 1946,
#  'family': 659,
#  'salary': 1486,
#  'thank': 1731,
#  'sura': 1689,
#  'didnt': 543,
#  'pleasure': 1324,
#  'company': 443,
#  'good': 771,
#  'weve': 1926,
#  'oh': 1238,
#  'message': 1123,
#  'sent': 1526,
#  'days': 520,
#  'ago': 166,
#  'watching': 1901,
#  'tv': 1814,
#  'meeting': 1116,
#  'sun': 1680,
#  'sleep': 1581,
#  'medicine': 1112,
#  'staying': 1645,
#  'dad': 504,
#  'service': 1531,
#  'announcement': 190,
#  'recently': 1420,
#  'tried': 1798,
#  'delivery': 534,
#  'unable': 1829,
#  'late': 988,
#  'said': 1485,
#  'website': 1910,
#  'dont': 574,
#  'private': 1365,
#  '2003': 51,
#  'account': 145,
#  'statement': 1642,
#  'shows': 1555,
#  '800': 111,
#  'unredeemed': 1838,
#  'points': 1338,
#  'identifier': 885,
#  'code': 426,
#  'expires': 647,
#  'prize': 1366,
#  'trying': 1806,
#  'contact': 460,
#  'todays': 1773,
#  'draw': 580,
#  '2000': 50,
#  'guaranteed': 788,
#  'land': 984,
#  'line': 1020,
#  'valid': 1857,
#  '12hrs': 33,
#  'sat': 1489,
#  'right': 1460,
#  'guess': 790,
#  'pub': 1375,
#  'happy': 812,
#  'pig': 1305,
#  'saying': 1497,
#  'aiyah': 176,
#  'pls': 1326,
#  'yo': 2007,
#  'work': 1963,
#  'princess': 1364,
#  'love': 1058,
#  'times': 1761,
#  'night': 1212,
#  'thats': 1735,
#  'problem': 1369,
#  'latest': 990,
#  'ipod': 918,
#  'mp3': 1174,
#  'player': 1320,
#  '400': 83,
#  'win': 1938,
#  '83355': 115,
#  'training': 1793,
#  'college': 433,
#  'way': 1904,
#  'skip': 1577,
#  'outside': 1264,
#  'house': 865,
#  'god': 762,
#  'coming': 439,
#  'change': 388,
#  'tat': 1705,
#  'mom': 1156,
#  'crazy': 482,
#  'dear': 523,
#  'mood': 1164,
#  'drive': 586,
#  'brother': 327,
#  'lemme': 1005,
#  'swing': 1696,
#  'basically': 256,
#  'time': 1760,
#  'semester': 1522,
#  'forgot': 706,
#  'ask': 220,
#  'smth': 1594,
#  'theres': 1738,
#  'card': 365,
#  'present': 1359,
#  'lei': 1004,
#  'want': 1891,
#  'write': 1975,
#  'sign': 1561,
#  'gonna': 770,
#  'bored': 306,
#  'death': 524,
#  'day': 519,
#  'internet': 913,
#  'video': 1864,
#  'camera': 359,
#  'phones': 1294,
#  'half': 800,
#  'price': 1363,
#  'rental': 1438,
#  '12': 32,
#  'mths': 1180,
#  '500': 93,
#  'mins': 1134,
#  '100': 21,
#  'txts': 1820,
#  'mobileupd8': 1151,
#  'haha': 797,
#  'used': 1848,
#  'driving': 587,
#  'usf': 1850,
#  'lot': 1053,
#  '10': 20,
#  'min': 1131,
#  'youre': 2013,
#  'sure': 1690,
#  'xavier': 1986,
#  'smoke': 1591,
#  'told': 1775,
#  'alright': 183,
#  'bring': 321,
#  'age': 163,
#  'chill': 405,
#  'ordered': 1259,
#  'ringtone': 1462,
#  'order': 1258,
#  'england': 616,
#  'poly': 1340,
#  'colour': 434,
#  'game': 737,
#  'optout': 1254,
#  'vodafone': 1871,
#  'numbers': 1229,
#  'ending': 613,
#  'selected': 1517,
#  '350': 72,
#  'award': 239,
#  'number': 1228,
#  'matches': 1097,
#  'claim': 415,
#  'wine': 1939,
#  'lady': 983,
#  'receive': 1418,
#  'check': 397,
#  'gets': 752,
#  'questions': 1385,
#  '4mths': 88,
#  'orange': 1256,
#  '11mths': 31,
#  'mobilesdirect': 1150,
#  '08000938767': 4,
#  'update': 1841,
#  'or2stoptxt': 1255,
#  'came': 358,
#  'hostel': 860,
#  'probably': 1368,
#  'gas': 742,
#  'cash': 374,
#  'tomorrow': 1778,
#  'wanna': 1890,
#  'cum': 492,
#  '2nite': 66,
#  'chat': 394,
#  'xx': 1989,
#  'fine': 686,
#  'babes': 245,
#  'aint': 172,
#  'tho': 1748,
#  'saw': 1495,
#  'movie': 1172,
#  'yest': 2002,
#  'quite': 1388,
#  'funny': 732,
#  '2mrw': 64,
#  'afternoon': 161,
#  'disturb': 560,
#  'anymore': 195,
#  'wants': 1894,
#  'morning': 1167,
#  'plz': 1328,
#  'sir': 1568,
#  'tonight': 1781,
#  'food': 701,
#  'really': 1412,
#  'nice': 1209,
#  'simply': 1565,
#  'sitting': 1574,
#  'match': 1096,
#  'office': 1237,
#  'aight': 171,
#  'leh': 1003,
#  'tuition': 1811,
#  'looking': 1045,
#  'lessons': 1007,
#  'dai': 506,
#  'gentle': 750,
#  'baby': 246,
#  'soon': 1609,
#  'taking': 1700,
#  'deep': 529,
#  'inside': 907,
#  'pussy': 1379,
#  'gotta': 778,
#  'hit': 838,
#  'people': 1285,
#  'amp': 187,
#  'community': 441,
#  'rock': 1466,
#  'dude': 593,
#  'arrested': 216,
#  'sister': 1571,
#  'leave': 997,
#  'medical': 1111,
#  'forward': 707,
#  'feel': 674,
#  'evening': 631,
#  'wonderful': 1957,
#  'plans': 1317,
#  'life': 1015,
#  'begin': 271,
#  'anytime': 196,
#  'new': 1205,
#  'address': 154,
#  'complete': 445,
#  'especially': 627,
#  'personal': 1288,
#  'changed': 389,
#  'realized': 1411,
#  'says': 1498,
#  'drug': 590,
#  'able': 138,
#  'eat': 602,
#  'sleeping': 1582,
#  'nt': 1225,
#  'feeling': 675,
#  'escape': 626,
#  'theatre': 1736,
#  'watch': 1900,
#  'minutes': 1136,
#  'safe': 1484,
#  'miss': 1139,
#  'real': 1409,
#  '1000': 22,
#  'pretty': 1361,
#  'girl': 757,
#  'stay': 1644,
#  'bed': 268,
#  'pass': 1278,
#  'seeing': 1515,
#  'missed': 1140,
#  'gr8': 780,
#  'hey': 831,
#  'meet': 1114,
#  'dinner': 552,
#  'jess': 939,
#  'eve': 630,
#  'xxx': 1990,
#  'ring': 1461,
#  'pictures': 1302,
#  'facebook': 654,
#  'thought': 1749,
#  'living': 1028,
#  'perfect': 1286,
#  'partner': 1276,
#  'join': 943,
#  'thing': 1740,
#  'sentence': 1527,
#  'concentrate': 449,
#  'career': 367,
#  'leaving': 999,
#  'wanted': 1892,
#  'shit': 1547,
#  'guys': 793,
#  'bud': 334,
#  'started': 1638,
#  'wifehow': 1935,
#  'knew': 975,
#  'murder': 1185,
#  'exactly': 636,
#  'slow': 1585,
#  'using': 1851,
#  'glad': 761,
#  'following': 699,
#  'dreams': 582,
#  'yes': 2001,
#  'speak': 1619,
#  'friday': 718,
#  'finally': 685,
#  'lunch': 1072,
#  'today': 1772,
#  'stomach': 1650,
#  'better': 277,
#  'lose': 1048,
#  'weight': 1920,
#  'actually': 149,
#  'weeks': 1919,
#  'start': 1637,
#  'putting': 1380,
#  'ad': 150,
#  'docs': 563,
#  'tired': 1762,
#  'stuff': 1666,
#  'ugh': 1824,
#  'normal': 1221,
#  'body': 297,
#  'double': 578,
#  'linerental': 1021,
#  'motorola': 1170,
#  'sonyericsson': 1608,
#  '08000839402': 2,
#  'member': 1119,
#  'visit': 1868,
#  'months': 1163,
#  'cause': 378,
#  'dave': 518,
#  'final': 684,
#  'notice': 1224,
#  'collect': 430,
#  'tenerife': 1724,
#  'holiday': 848,
#  '5000': 94,
#  'landline': 985,
#  'tcs': 1710,
#  'sae': 1483,
#  'cw25wx': 502,
#  '150ppm': 40,
#  'true': 1801,
#  '0845': 6,
#  'tones': 1780,
#  'end': 611,
#  'monday': 1160,
#  'hour': 863,
#  'isnt': 922,
#  'frnd': 723,
#  'imagine': 892,
#  'urself': 1846,
#  'cell': 383,
#  'wat': 1899,
#  'abt': 139,
#  'frnds': 724,
#  'jst': 950,
#  'goodmorning': 772,
#  'hospital': 859,
#  'return': 1453,
#  'hungry': 875,
#  'wot': 1973,
#  'hows': 867,
#  'bugis': 336,
#  'oni': 1247,
#  'busy': 340,
#  'wun': 1979,
#  'sleepingand': 1583,
#  'surfing': 1692,
#  'drink': 584,
#  'plenty': 1325,
#  'water': 1902,
#  'trip': 1799,
#  'lor': 1047,
#  'uni': 1834,
#  'starts': 1640,
#  'cos': 469,
#  'jus': 952,
#  'yr': 2015,
#  'project': 1372,
#  'wow': 1974,
#  'shopping': 1550,
#  'try': 1805,
#  'lost': 1052,
#  'fact': 655,
#  'feb': 672,
#  'dis': 557,
#  'valued': 1858,
#  'evn': 632,
#  'comes': 437,
#  'ull': 1827,
#  'gt': 787,
#  'married': 1093,
#  'person': 1287,
#  'ignore': 888,
#  'thanx': 1734,
#  'school': 1501,
#  'direct': 554,
#  '2u': 69,
#  'rply': 1476,
#  'title': 1764,
#  '8007': 113,
#  'titles': 1765,
#  'unique': 1835,
#  'user': 1849,
#  '87239': 124,
#  'services': 1532,
#  'buy': 341,
#  'pic': 1297,
#  'msgs': 1179,
#  'cashbalance': 375,
#  'currently': 495,
#  'pounds': 1352,
#  'maximize': 1103,
#  'cashin': 376,
#  '86688': 119,
#  '150pmsg': 39,
#  'cc': 380,
#  '08718720201': 15,
#  'po': 1330,
#  'box': 313,
#  '11414': 30,
#  'tcrw1': 1709,
#  'finished': 689,
#  'daddy': 505,
#  'scream': 1503,
#  'slap': 1579,
#  'ass': 227,
#  'dick': 540,
#  'men': 1120,
#  'sounds': 1615,
#  'pay': 1282,
#  'stock': 1648,
#  'comin': 438,
#  'basic': 255,
#  'yoga': 2008,
#  'course': 476,
#  'pilates': 1306,
#  'iscoming': 920,
#  'forever': 704,
#  'test': 1726,
#  'earth': 599,
#  'losing': 1050,
#  'tc': 1708,
#  'whats': 1927,
#  'room': 1469,
#  'easy': 601,
#  'reason': 1414,
#  'convey': 464,
#  'regards': 1426,
#  'believe': 273,
#  'things': 1741,
#  'beautiful': 266,
#  'library': 1012,
#  '4th': 90,
#  'wife': 1934,
#  'husband': 879,
#  'marry': 1094,
#  'died': 546,
#  'th': 1730,
#  'question': 1383,
#  'hell': 826,
#  'great': 783,
#  'worry': 1970,
#  'rs': 1478,
#  'egg': 606,
#  'gud': 789,
#  'ni8': 1208,
#  'chillin': 406,
#  'looks': 1046,
#  'prob': 1367,
#  'laptop': 986,
#  'fixed': 692,
#  'cuz': 501,
#  'yep': 2000,
#  'yesterday': 2003,
#  'freemsg': 713,
#  'reward': 1457,
#  'hours': 864,
#  'use': 1847,
#  'frm': 722,
#  'tht': 1752,
#  'mad': 1078,
#  'woke': 1952,
#  'yeah': 1997,
#  'weekend': 1916,
#  'bought': 310,
#  'getting': 754,
#  'texts': 1729,
#  'pound': 1351,
#  '900': 130,
#  'calls': 355,
#  'wen': 1923,
#  'lovable': 1057,
#  'bcums': 264,
#  'angry': 189,
#  'wid': 1932,
#  'seriously': 1530,
#  'coz': 478,
#  'childish': 403,
#  'showing': 1554,
#  'affection': 158,
#  'kettoda': 962,
#  'manda': 1088,
#  'roommates': 1471,
#  'mum': 1182,
#  'messages': 1125,
#  'rest': 1450,
#  'masters': 1095,
#  'paying': 1283,
#  'doesnt': 566,
#  'did': 542,
#  'job': 941,
#  'kiss': 971,
#  'smile': 1588,
#  'sea': 1506,
#  'ic': 881,
#  'meant': 1109,
#  'bit': 288,
#  'left': 1001,
#  'hmmm': 842,
#  'feet': 677,
#  'ready': 1408,
#  'date': 514,
#  'kind': 968,
#  'urgent': 1844,
#  'weekends': 1917,
#  'kb': 958,
#  'power': 1353,
#  'dunno': 595,
#  'thk': 1746,
#  'oso': 1263,
#  'liao': 1011,
#  'complimentary': 447,
#  'ibiza': 880,
#  '10000': 23,
#  'await': 236,
#  'collection': 432,
#  'ppm': 1356,
#  '18': 43,
#  'expecting': 644,
#  'battery': 260,
#  'download': 579,
#  'movies': 1173,
#  'away': 241,
#  'confirm': 453,
#  'bank': 252,
#  'issues': 924,
#  '300': 70,
#  'dresser': 583,
#  'short': 1551,
#  'look': 1042,
#  'birthday': 286,
#  'dun': 594,
#  'hard': 813,
#  'failed': 656,
#  'shes': 1544,
#  'sad': 1482,
#  'wed': 1911,
#  'aha': 168,
#  'important': 895,
#  'information': 905,
#  'log': 1034,
#  'httpwwwurawinnercom': 871,
#  'fantastic': 662,
#  'surprise': 1693,
#  'awaiting': 237,
#  'details': 538,
#  'okie': 1242,
#  'working': 1965,
#  'eyes': 652,
#  'philosophy': 1292,
#  'fool': 702,
#  'march': 1090,
#  'early': 598,
#  'izzit': 929,
#  'spending': 1625,
#  'quality': 1381,
#  'sit': 1572,
#  'wait': 1880,
#  'summer': 1679,
#  'magical': 1079,
#  'sight': 1560,
#  'white': 1930,
#  'snow': 1596,
#  'wylie': 1985,
#  'friend': 719,
#  'darren': 512,
#  'considering': 458,
#  'mah': 1080,
#  'wont': 1960,
#  'depends': 536,
#  'wan': 1888,
#  'howz': 868,
#  'forwarded': 708,
#  'sms': 1593,
#  'alert': 181,
#  'walked': 1886,
#  'moms': 1158,
#  'hill': 836,
#  'hate': 815,
#  'accept': 143,
#  'single': 1566,
#  'eerie': 605,
#  '4u': 91,
#  'wwwgetzedcouk': 1982,
#  'pobox36504w45wq': 1333,
#  '150p': 37,
#  'appt': 205,
#  'die': 545,
#  'worried': 1968,
#  'listen': 1024,
#  'thinkin': 1743,
#  'kkhow': 973,
#  'area': 209,
#  '1000s': 24,
#  'jay': 936,
#  'sound': 1614,
#  'darlin': 510,
#  'film': 683,
#  'mate': 1098,
#  'month': 1162,
#  'weed': 1914,
#  'alcohol': 180,
#  'london': 1038,
#  'big': 280,
#  'missing': 1141,
#  'okay': 1240,
#  'delivered': 533,
#  '200': 49,
#  'camcorder': 357,
#  'posted': 1350,
#  'couple': 475,
#  'pics': 1301,
#  'fb': 671,
#  'waking': 1884,
#  'bishan': 287,
#  'tot': 1785,
#  'open': 1250,
#  'near': 1198,
#  'makes': 1084,
#  'forget': 705,
#  'noon': 1218,
#  'welcome': 1922,
#  'giving': 760,
#  'calling': 354,
#  'future': 733,
#  'billed': 282,
#  'daily': 507,
#  'cancel': 361,
#  'february': 673,
#  'wish': 1943,
#  'network': 1203,
#  'operator': 1251,
#  'cs': 489,
#  'urgnt': 1845,
#  'laugh': 992,
#  'reach': 1403,
#  'ltdecimalgt': 1068,
#  'cannt': 363,
#  'tmobile': 1768,
#  'sim': 1563,
#  'loyalty': 1065,
#  'ends': 614,
#  'apply': 202,
#  'building': 337,
#  'sick': 1558,
#  'wear': 1907,
#  'gym': 794,
#  'vote': 1874,
#  'party': 1277,
#  'took': 1783,
#  'tablets': 1698,
#  'current': 494,
#  'morphine': 1168,
#  'decide': 526,
#  'faster': 666,
#  'sis': 1570,
#  'ki': 964,
#  'players': 1321,
#  'todaysundaysunday': 1774,
#  'holidayso': 849,
#  'choose': 410,
#  'babe': 244,
#  'asked': 222,
#  'far': 664,
#  'thinking': 1744,
#  'doing': 571,
#  'wonders': 1959,
#  'world': 1967,
#  '7th': 110,
#  '6th': 105,
#  'style': 1668,
#  '5th': 100,
#  'personality': 1289,
#  '3rd': 79,
#  'nature': 1196,
#  '2nd': 65,
#  'lovely': 1060,
#  'friendship': 721,
#  'spent': 1626,
#  'bin': 283,
#  'possible': 1348,
#  'sucks': 1676,
#  'planned': 1315,
#  'valentine': 1855,
#  'voucher': 1875,
#  'holder': 846,
#  'offer': 1235,
#  'pc': 1284,
#  'tscs': 1807,
#  'hear': 820,
#  'country': 474,
#  'fall': 658,
#  'asleep': 226,
#  'middle': 1128,
#  'walk': 1885,
#  'booked': 302,
#  'cheers': 400,
#  'year': 1998,
#  'skype': 1578,
#  'haf': 796,
#  'lect': 1000,
#  'dat': 513,
#  'oredi': 1260,
#  'lots': 1054,
#  'biggest': 281,
#  'cock': 425,
#  'action': 147,
#  'mail': 1081,
#  'making': 1085,
#  'tonite': 1782,
#  'invited': 916,
#  'understanding': 1833,
#  'small': 1587,
#  'bslvyl': 329,
#  'shirt': 1545,
#  'ones': 1246,
#  'budget': 335,
#  'abi': 136,
#  'contract': 463,
#  'ran': 1395,
#  'damn': 508,
#  'poor': 1344,
#  'stand': 1634,
#  'chance': 387,
#  'hiya': 839,
#  'naughty': 1197,
#  'minute': 1135,
#  'ufind': 1823,
#  'rreveal': 1477,
#  'specialcall': 1621,
#  'youve': 2014,
#  'years': 1999,
#  'boy': 314,
#  'quick': 1386,
#  'awarded': 240,
#  'bonus': 299,
#  'caller': 351,
#  'december': 525,
#  'entitled': 622,
#  '08002986906': 5,
#  'nvm': 1230,
#  'sport': 1631,
#  'yar': 1995,
#  'raining': 1394,
#  'password': 1280,
#  'queen': 1382,
#  'wishing': 1945,
#  'abiola': 137,
#  'pop': 1345,
#  'available': 234,
#  'finish': 688,
#  'parents': 1274,
#  'girls': 758,
#  'india': 900,
#  'somebody': 1604,
#  'havent': 817,
#  'stuck': 1662,
#  'orchard': 1257,
#  'car': 364,
#  'face': 653,
#  'realy': 1413,
#  'hot': 861,
#  'wana': 1889,
#  'wnt': 1951,
#  'nw': 1231,
#  'keeping': 959,
#  'rd': 1402,
#  'adult': 156,
#  'content': 462,
#  'shortly': 1552,
#  'round': 1473,
#  'birla': 285,
#  'soft': 1599,
#  'easier': 600,
#  'aft': 160,
#  'str': 1656,
#  'joking': 946,
#  'gorgeous': 775,
#  'ron': 1468,
#  'shuhui': 1556,
#  'congrats': 454,
#  '3g': 75,
#  'videophones': 1866,
#  'videochat': 1865,
#  'mates': 1099,
#  'play': 1318,
#  'java': 935,
#  'games': 738,
#  'dload': 561,
#  'music': 1188,
#  'noline': 1217,
#  'rentl': 1439,
#  'yahoo': 1993,
#  'mode': 1153,
#  'sha': 1537,
#  'vry': 1877,
#  'amt': 188,
#  'lt3': 1067,
#  'case': 373,
#  'cheap': 396,
#  'book': 301,
#  'cancer': 362,
#  'freak': 710,
#  'wrong': 1976,
#  'hes': 830,
#  'bluetooth': 296,
#  'dvd': 596,
#  'instructions': 909,
#  'road': 1465,
#  'enter': 620,
#  'weekly': 1918,
#  '250': 58,
#  'gift': 755,
#  'store': 1654,
#  'age16': 164,
#  'slept': 1584,
#  'hopefully': 856,
#  'ppl': 1354,
#  'randomly': 1397,
#  'pm': 1329,
#  'online': 1248,
#  'meh': 1117,
#  'truth': 1804,
#  'gravity': 782,
#  'read': 1406,
#  'carefully': 369,
#  'heart': 822,
#  'feels': 676,
#  ...}

# %%
vector.get_feature_names_out()
# Out:
# array(['020603', '0800', '08000839402', ..., 'yummy', 'yup', 'zed'],
#       dtype=object)

# %%
# transform the words into Document Term Matrix -DTM
DTM_train = vector.transform(Xtrain)
DTM_test = vector.transform(Xtest)

# %% [markdown]
# **Email Classification Models**

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

RF_model = RandomForestClassifier(n_estimators=150, random_state=0)
RF_model.fit(DTM_train, ytrain)
# Out:
# RandomForestClassifier(n_estimators=150, random_state=0)

# %%
from sklearn import metrics
ytest_predict = RF_model.predict(DTM_test)
model_score =RF_model.score(DTM_test, ytest)
print(model_score)


print(metrics.confusion_matrix(ytest, ytest_predict))
print(metrics.classification_report(ytest, ytest_predict))
# Out:
# 0.9842067480258435
# [[1208    0]
#  [  22  163]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1208
#            1       1.00      0.88      0.94       185
#
#     accuracy                           0.98      1393
#    macro avg       0.99      0.94      0.96      1393
# weighted avg       0.98      0.98      0.98      1393

# %% [markdown]
# **KNN Models**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn =KNeighborsClassifier()
knn.fit(DTM_train, ytrain)
# Out:
# KNeighborsClassifier()

# %%
ytest_predict = knn.predict(DTM_test)
model_score =knn.score(DTM_test, ytest)
print(model_score)


print(metrics.confusion_matrix(ytest, ytest_predict))
print(metrics.classification_report(ytest, ytest_predict))
# Out:
# 0.9203158650394831
# [[1207    1]
#  [ 110   75]]
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      1208
#            1       0.99      0.41      0.57       185
#
#     accuracy                           0.92      1393
#    macro avg       0.95      0.70      0.77      1393
# weighted avg       0.93      0.92      0.91      1393

# %% [markdown]
# **TFIDF VECTORIZER**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer (max_features=2000, min_df=3, max_df=0.85)

# %%
vectorizer.fit(Xtrain)
# Out:
# TfidfVectorizer(max_df=0.85, max_features=2000, min_df=3)

# %%
# transform the words into TFIDF
TFIDF_train = vectorizer.transform(Xtrain)
TFIDF_test = vectorizer.transform(Xtest)

# %%
TFIDF_train
# Out:
# <4179x2000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 30815 stored elements in Compressed Sparse Row format>

# %%
TFIDF_train.shape
# Out:
# (4179, 2000)

# %% [markdown]
# **Random Forest**

# %%
RF_model = RandomForestClassifier(n_estimators=150, random_state=0)
RF_model.fit(TFIDF_train, ytrain)
# Out:
# RandomForestClassifier(n_estimators=150, random_state=0)

# %%
ytest_predict = RF_model.predict(TFIDF_test)
model_score =RF_model.score(TFIDF_test, ytest)
print(model_score)


print(metrics.confusion_matrix(ytest, ytest_predict))
print(metrics.classification_report(ytest, ytest_predict))
# Out:
# 0.9827709978463748
# [[1208    0]
#  [  24  161]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1208
#            1       1.00      0.87      0.93       185
#
#     accuracy                           0.98      1393
#    macro avg       0.99      0.94      0.96      1393
# weighted avg       0.98      0.98      0.98      1393

# %% [markdown]
# **Support Vector Machines- SVM**

# %%
from sklearn.svm import SVC

# %%
svc_model = SVC(random_state=0)
svc_model.fit(TFIDF_train, ytrain)
# Out:
# SVC(random_state=0)

# %%
ytest_predict = svc_model.predict(TFIDF_test)
model_score =svc_model.score(TFIDF_test, ytest)
print(model_score)


print(metrics.confusion_matrix(ytest, ytest_predict))
print(metrics.classification_report(ytest, ytest_predict))
# Out:
# 0.9863603732950467
# [[1208    0]
#  [  19  166]]
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1208
#            1       1.00      0.90      0.95       185
#
#     accuracy                           0.99      1393
#    macro avg       0.99      0.95      0.97      1393
# weighted avg       0.99      0.99      0.99      1393
